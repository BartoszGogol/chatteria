# %% [markdown]
# Zadanie 1
# Które z następujących zadań wymagają w Twojej opinii inteligencji od człowieka:
#
# • wypełnianie deklaracji PIT,     NIE
#
# • streszczanie tekstu,   TAK
#
# • tłumaczenie tekstu,   TAK
#
# • klasyfikacja tekstu do kategorii tematycznych,   NIE
#
# • odpowiadanie na proste pytania zadawane w języku naturalnym (np. polskim), NIE
#
# • układanie rozkładu jazdy transportu miejskiego,   TAK
#
# • programowanie (pisanie programów komputerowych),   TAK
#
# • „programowanie” kanałów telewizyjnych,   NIE
#
# • testowanie oprogramowania,   NIE
#
# • komponowanie muzyki,   TAK
#
# • rozwiązywanie układów równań,   TAK
#
# • symboliczne obliczanie pochodnych funkcji,   TAK
#
# • symboliczne całkowanie funkcji,   TAK
#
# • kierowanie samochodem.   TAK
#
# Zadanie 2
# Które z następujących problemów można uznać za mieszczące się w zakresie sztucznej inteligencji:
#
# • streszczanie tekstu, NIE
#
# • tłumaczenie tekstu, NIE
#
# • klasyfikacja tekstu do kategorii tematycznych, NIE
#
# • odpowiadanie na proste pytania zadawane w języku naturalnym, NIE
#
# • rozwiązywanie układów równań, NIE
#
# • układanie rozkładu jazdy, NIE
#
# • rozwiązywanie układów równań liniowych, NIE
#
# • symboliczne obliczanie pochodnych, NIE
#
# • symboliczne całkowanie, NIE
#
# • kierowanie samochodem. NIE
#
# O ile rozumieć, czy sztuczna inteligencja radzi sobie z problemem.
#
# Zadanie 3
# Które z poniższych rodzajów komunikacyjnego zachowania człowieka mogą być
# obecnie skutecznie imitowane przez sztuczne systemy (odpowiednio oprogramowane
# maszyny):
#
# • rozmowa towarzyska,   TAK
#
# • dyskusja polityczna,   TAK
#
# • dyskusja naukowa,   TAK
#
# • odpowiadanie na pytania klientów w telefonicznej infolinii,   TAK
#
# • odpowiadanie na pytania klientów w internetowej infolinii.   TAK
#
# Zadanie 4
# Do zadań skorzystaj z załączonej listy Chatbotów (Chatterbotów) lub znajdź własne.
# 1. Przeprowadź rozmowę z chatbotem. Spróbuj zdefiniować różnice pomiędzy
# botem udającym człowieka (przygotowywanym na test Turinga) a botem
# „asystentem, służącym”.
# 2. Sprawdź dwa boty z obu z tych rodzajów na występowanie zachowań:
# a) opowiadanie żartów,
# b) przytaczanie cytatów z twoich wypowiedzi, lub znanych osób,
# c) nawiązywanie wypowiedzi do słów kluczowych,
# d) zadawanie dużej liczby pytań,
# e) powracanie do początku wypowiedzi, sekwencyjne powtarzanie,
# f) zadawanie pytań powstających z twoich wypowiedzi,
# g) odpowiadanie wymijająco, ogólnikowo,
# h) częsta zmiana tematu rozmowy,
# i) problemy z utrzymaniem wątków.
# 3. Sporządź raport ze spostrzeżeń.
# 4. Na podstawie powyższych obserwacji, w grupie dwóch osób spróbujcie przewidzieć zachowania dwóch rozmawiających ze sobą chatbotów (przepisując ich
# wzajemne odpowiedzi).
# 5. Zdenerwuj bota 😊😊
#
#
# Lista startowa chatbotów:
#
# • cleverbot.com
#
# • www.chatbot4u.com
#
# • www.chatbot.pl
#
# • douweosinga.com
#
# • apps.facebook.com/luxoft_avatar
#
# • chatterboty.pl
#
# • ikea.com.pl (zapytaj Anię)
#
# • www.chatbots.org
#
# • www.snikers.pl
#
# • www.personalityforge.com (hall of fame)
#
# • www.ecreation.pl
#
# • wellbot.tk
#
# • www.inguaris.pl
#
# • tremo.algit.pl
