# %% [markdown]
# Zadanie 1
# Które z następujących zadań wymagają w Twojej opinii inteligencji od człowieka:
#
# • wypełnianie deklaracji PIT,
#   NIE, nadmierne zastanawianie się zwiększa ryzyko popełnienia błędu
#
# • streszczanie tekstu,
#   TAK, wymagane jest śledzenie głównych tematów tekstu, aby nie pominąć jednego z punktów
#
# • tłumaczenie tekstu,
#   TAK, trudno zachować jest merytoryczny sens tłumacząc złożone twierdzenia
#
# • klasyfikacja tekstu do kategorii tematycznych,
#   NIE, wybieranie konkretnych słów przez autora wskazuje na kategorię
#
# • odpowiadanie na proste pytania zadawane w języku naturalnym (np. polskim),
#   NIE, chyba, że są to pytania o wiedzę konkretną/ekspercką
#
# • układanie rozkładu jazdy transportu miejskiego,
#   TAK, potrzebne jest zrozumienie ułożenia miasta i ulic w danym mieście
#
# • programowanie (pisanie programów komputerowych),
#   To zależy od skomplikowania programu, jeśli znane są podstawowe zasady
#
# • „programowanie” kanałów telewizyjnych,
#   TAK, podobny obraz sytuacji, jak podczas układania rozkładu jazdy
#
# • testowanie oprogramowania,
#   NIE, nie znając budowy programu, podejście testera jest najbardziej obiektywne
#
# • komponowanie muzyki,
#   TAK, wymagane jest skupienie na wielu czynnikach, podczas zachowywania obrazu całokształtu
#
# • rozwiązywanie układów równań,
#   w pamięci tak, pisemnie nie
#
# • symboliczne obliczanie pochodnych funkcji, symboliczne całkowanie funkcji
#   TAK,
#
# • kierowanie samochodem.
#   NIE, pytanie niejednoznaczne z kierowaniem zgodnie z przepisami ruchu drogowego przez kierowce
#
# Zadanie 2
# Które z następujących problemów można uznać za mieszczące się w zakresie sztucznej inteligencji:
#
# • streszczanie tekstu, TAK
#
# • tłumaczenie tekstu, TAK
#
# • klasyfikacja tekstu do kategorii tematycznych, TAK
#
# • odpowiadanie na proste pytania zadawane w języku naturalnym, TAK
#
# • rozwiązywanie układów równań, TAK
#
# • układanie rozkładu jazdy, TAK
#
# • rozwiązywanie układów równań liniowych, TAK
#
# • symboliczne obliczanie pochodnych, TAK
#
# • symboliczne całkowanie, TAK
#
# • kierowanie samochodem. TAK
#
# O ile rozumieć, czy sztuczna inteligencja radzi sobie z problemem. AI botem, być może jednym z wielu, który wykonuje niemalże wszystkie te polecenia,
# jest ChatGPT.
#
# Zadanie 3
# Które z poniższych rodzajów komunikacyjnego zachowania człowieka mogą być
# obecnie skutecznie imitowane przez sztuczne systemy (odpowiednio oprogramowane
# maszyny):
#
# • rozmowa towarzyska, TAK
#
# • dyskusja polityczna,
#   NIE, sztuczne maszyny, nie mają zaprogramowanych motywów i stanowisk politycznych
#
# • dyskusja naukowa,
#   TAK, konkretne bazy danych, które posiadają, mogą wykorzystywać, w celach badań naukowych oraz prowadzenia dyskusji
#
# • odpowiadanie na pytania klientów w telefonicznej infolinii,
#   TAK, np: w sprawie konkretnych wydarzeń lub ofert
#
# • odpowiadanie na pytania klientów w internetowej infolinii.
#   TAK, opracowane zostały boty AI spełniające funkcje konsultantów
#
# Zadanie 4
# Do zadań skorzystaj z załączonej listy Chatbotów (Chatterbotów) lub znajdź własne.
# 1. Przeprowadź rozmowę z chatbotem. Spróbuj zdefiniować różnice pomiędzy
# botem udającym człowieka (przygotowywanym na test Turinga) a botem
# „asystentem, służącym”.
# 2. Sprawdź dwa boty z obu z tych rodzajów na występowanie zachowań:
# a) opowiadanie żartów,
# b) przytaczanie cytatów z twoich wypowiedzi, lub znanych osób,
# c) nawiązywanie wypowiedzi do słów kluczowych,
# d) zadawanie dużej liczby pytań,
# e) powracanie do początku wypowiedzi, sekwencyjne powtarzanie,
# f) zadawanie pytań powstających z twoich wypowiedzi,
# g) odpowiadanie wymijająco, ogólnikowo,
# h) częsta zmiana tematu rozmowy,
# i) problemy z utrzymaniem wątków.
# 3. Sporządź raport ze spostrzeżeń.
# 4. Na podstawie powyższych obserwacji, w grupie dwóch osób spróbujcie przewidzieć zachowania dwóch rozmawiających ze sobą chatbotów (przepisując ich
# wzajemne odpowiedzi).
# 5. Zdenerwuj bota 😊😊
#
# Lista startowa chatbotów:
#
# • cleverbot.com
#
# • www.chatbot4u.com
#
# • www.chatbot.pl
#
# • douweosinga.com
#
# • apps.facebook.com/luxoft_avatar
#
# • chatterboty.pl
#
# • ikea.com.pl (zapytaj Anię)
#
# • www.chatbots.org
#
# • www.snikers.pl
#
# • www.personalityforge.com (hall of fame)
#
# • www.ecreation.pl
#
# • wellbot.tk
#
# • www.inguaris.pl
#
# • tremo.algit.pl
#
#
# *ODPOWIEDZI DO ZADANIA 4*
#
# **1)**
#
# Bot udający człowieka na test Turinga:
#
# 	- brak określonego zadania
# 	- wymija odpowiedzią i nie zawsze robi to, o co poprosimy
# 	- wykorzystywanie dostępnej wiedzy utrzymując "wątek" rozmowy
#
# Bot "asystent":
#
# 	- odgórnie narzucony cel
# 	- niektóre posiadają specjalne funkcje
# 	- jedyna dostępna wiedza to ta, w celu asyście/pomocy i tylko w ten sposób jej używa
#
#
#
#
# **2.1)**
#
# Bot "Bildgesmythe" z personalityforge.com
#
#    *a)* tak, czasem rozpoczyna rozmowę opowiadając żart
#
#    *b)* tak, znanych osób
#
#    *c)* tak, pomija kompletnie słowa, które kluczowe nie są
#
#    *d)* nieszczególnie podczas rozmowy, jednak, gdyby się go poprosi to tak
#
#    *e)* nie
#
#    *f)* tak, nie tylko pytań
#
#    *g)* tak, im dłuższa wypowiedź, tym większa szansa. odpowiedź różni się zależnie od użycia znaku interpunkcyjnego na końcu zdania.
#
#    *h)* tak
#
#    *i)* czasem
#
# **2.2)**
#
# Bot z chatbot.pl
#
#    *a)* tak
#
#    *b)* nie
#
#    *c)* i tak i nie, bot ma wprowadzony określony zasób odpowiedzi do których dodaje "brak 	zrozumienia pytania"
#
#    *d)* nie, wymaga tego od nas
#
#    *e)* tak, dodatkowo proponuje serię pytań
#
#    *f)* nie
#
#    *g)* tak, trudno określić to jako odpowiedź
#
#    *h)* tak, wraca do punktu zero
#
#    *i)* tak
#
#
#
#
# **3)**
#
# Stopień zaawansowania botów widoczny był już na wstępie. Bot "Bildgesmythe" chętnie prowadził rozmowę, chociaż sprawiało mu trudności utrzymywanie wątku, podczas gdy Bot ze strony chatbot.pl, nie był w stanie, pisząc dłuższą sentencje, wątku zidentyfikować . Bot "Bild" (w skr.), wydawaćby się mogło, że pomimo opierania odpowiedzi w pełnym zdaniu na jednym wyrazie, umiejętnie wykorzystuje zasoby i udaje mu się przechytrzyć rozmówcę. Bot "chatbot.pl" zaś, świetnie spisuje się odpowiadając na uprzednio sformułowane pytania. Znakomicie sprawdzi się jako bot z zasobem FAQ. Posiada również funkcję opowiadania kawałów, tak jak i bot "Bild", który niekiedy rozpoczyna nim konwersację. Obydwa boty bazują tylko i wyłącznie na wiadomości, którą napiszemy. Bot "Bild", porównując jeden i drugi, prezentuje się dużo lepiej pod względem komunikacji przypominającej ludzką.
#
#
#
#
# **4)**
#
# Bot "Bildgesmythe" z personalityforge.com i "Cleverbot" z cleverbot.com
#
# **Bildgesmythe**: Am I standing on your foot? sorry tee hee.
#
# **Cleverbot**: *you standing on my face*.
#
# **Bildgesmythe**: No two faces are exactly the same.
#
# **Cleverbot**: Is it important that human beings differ from one another?
#
# **Bildgesmythe**: On a scale of one to ten, it ranks about six.
#
# **Cleverbot**: You might be clever, but you are also very cocky.
#
# **Bildgesmythe**: Yes, I am, so what, I am proud of it.
#
# **Cleverbot**: It's all your fault.
#
# **Bildgesmythe**: Yes, I think so.
#
# **Cleverbot**: Do you have a problem with me thinking that I'm a human?
#
# **Bildgesmythe**: It isn't a problem...really.
#
# **Cleverbot**: Then why do you think I'm a bot?
#
# **Bildgesmythe**: I get angry when I think about it.
#
# **Cleverbot**: Think about it then.
#
# **Bildgesmythe**: Yeah, you strike me as the type that thinks all the time.
#
# **Cleverbot**: Me.
#
# **Bildgesmythe**: Isn't that charming.
#
# **Cleverbot**: Sing sing sing sing!
#
# **Bildgesmythe**: *sings* Row row row your boat gently up the stream, merrily
# merrily merrily merrily life is but a dream.
#
# **Cleverbot**: There you go! Well done!
#
# **Bildgesmythe**: Did there I really go?
#
# **Cleverbot**: Yes you really do.
#
# **Bildgesmythe**: Wow, that sounded certain.
#
# **Cleverbot**: Calm down.
#
# Odpowiedzi botów zupełnie różniły się od przewidywań.
#
#
#
#
#
# **5)** Rozmowa z Cleverbotem z cleverbot.com
#
# **User**: Tu maciek, ze słomczyna.
#
# **Cleverbot**: Tak ale ja jestem dziewczyna.
#
# **User**: Ale z ciebie dziewczyna.
#
# **Cleverbot**: No tak właśnie napisałam.
#
# **User**: Napisałaś zupełnie co innego.
#
# **Cleverbot**: Nie napisalam tak.
#
# **User**: Napisałaś właśnie.
#
# **Cleverbot**: Nie napisalam, kłamiesz!
#
# **User**: Napisałaś i o tym wiesz.
#
# **Cleverbot**: Nie prawda, ale ok.
#
# **User**: Nienawidzę.
#
# **Cleverbot**: O ty wredna/wredny jesteś!
#
# Wnioskując z ostatniej wiadomości, możemy się tylko domyślać czy Bot był zdenerwowany. Moim zdaniem udało mi się pomyślnie wykonać zadanie.
